# %%
from IPython.display import Image
import numpy as np
import pandas as pd

# %% [markdown]
# # Data Types

# %%
Image(filename='./resources/dataTypes.png')

# %% [markdown]
# FUNCTIONS PRESENT IN A CLASSS ARE CALLED METHODS. METHODS ARE FUNCTIONS THATS BELONG TO A PARTICULAR CLASS.

# %% [markdown]
# Even thought there's no need to specify a data type when declaring a variable in Python,<br>
# while allocating the necessary area in memory for the variable, the Python interpreter automatically<br>
# picks the most suitable built-in type for it.

# %% [markdown]
# # Useful Functions

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %% [markdown]
# # Mutability and Immutability

# %% [markdown]
# ### Mutability

# %% [markdown]
# An object is said to be MUTABLE if and only if It allows us to perform changes / Updations / Modifications at ```Same Address```

# %% [markdown]
# ### Immutability

# %% [markdown]
# An object is said to be IMMUTABLE if and only if It satisfies the following Properties:
# - It never allows to modify at  Same Address ( It allows us to  do the changes and changed value placed into Different Address
# - It never allows us to Perform "Item Assigment" (OR) does not support item assignment)

# %% [markdown]
# # Shallow Vs Deep Copy

# %% [markdown]
# copy module:
# - copy.copy() One Level Deep, only references of nested child objects
# - copy.deepcopy() full independent copy

# %% [markdown]
# ### Shallow Copy

# %% [markdown]
# 1) Intial Content of Both the Objects are SAME
# 2) The Memory Address (reference) of Both the Objects are DIFFERENT
# 3) Modifications are INDEPENDENT ( Whatever the changes we do on one object, It is not reflecting on anothetr object)

# %% [markdown]
# ### Deep Copy

# %% [markdown]
# 1) Intial Content of Both the Objects are SAME
# 2) The Memory Address (reference) of Both the Objects are SAME
# 3) Modifications are DEPENDENT ( Whatever the changes we do on one object, and  reflecting on anothetr object)

# %% [markdown]
# # 1) Fundatmental

# %% [markdown]
# ## 1.1 int

# %% [markdown]
# (0b,bin()),(0o,oct()),(0x,hex()),int(),int('0b101',2),format(\<int\>,'b')

# %% [markdown]
# ## 1.2 float

# %% [markdown]
# float()

# %% [markdown]
# ## 1.3 bool

# %% [markdown]
# bool() -----> True False
#
# false values:
# - None
# - False
# - 0, or any numerical value equivalent to zero, for example 0L, 0.0, 0j
# - Empty sequences: '', "", (), []
# - Empty mappings: {}
# - User-defined types where the \_\_bool__ or \_\_len__ methods return 0 or False
#
# All other values in Python evaluate to True.

# %% [markdown]
# ## 1.3 complex

# %% [markdown]
# - .real
# - .imag
# - complex(real,imag)
# - int-float-complex

# %% [markdown]
# # 2) Sequence

# %% [markdown]
# ## 2.1 str

# %% [markdown]
# ### general info

# %% [markdown]
# - str()
# - double quotes, single quotes, triple double quotes, triple single quotes
# - Indexing +ve -ve; strobj[index]
# - Slicing: End always Excluded (Pointing towards start)
# - strobj[start:end]
# - strobj[start:]
# - strobj[:end]
# - strobj[:]
# - strobj[start:end:step] (step can be +ve or -ve)
# - **in forward direction if end=0 then empty strobj**
# - **in backward direction if end=-1 then empty strobj**
# - We don't get IndexError when slicing, if conditions don't meet we get empty strobj.
# - lower case letter have higher ascii values than upper case letters.

# %% [markdown]
# ### methods

# %% [markdown]
# - .captilize()
# - .title()
# - .swapcase()
# - .upper()
# - .lower()
# ***
# - .strip([chars])
# - .lstrip([chars]) ----> e.g. s.lstrip('.+ ') --> remove .'s +'s and spaces similar to RegEX
# - .rstrip([chars])
# ***
# - .replace(old,new[,count])
# ***
# - .index(sub[,start[,end]) VE
# - .rindex(sub[,start[,end]) VE
# - .find(sub[,start[,end]) -1 ---> start finding from left
# - .rfind(sub[,start[,end]) -1 ----> starts finding from the right
# - .count(sub[,start[,end])
# ***
# - listObj = strObj.split(sep[,max_split]) / .rsplit(sep[,max_split])
# - .splitlines([keepends=True/False])
# ***
# - strObj.join(iterable)
# ***
# - .ljust(width[,fill])
# - .rjust(width[,fill])
# - .center(width[,fill])
# ***
# - .islower()
# - .isupper()
# - .isdigit()
# - .isalpha()
# - .isalnum()
# - .isspace()
# - .endswith(prefix[,start[,end]])
# - .startswith(prefix[,start[,end]])
# - .isascii()
# - .isidentifier()
# - .isprintable()
# - .isdigit()
# - .isdecimal()
# - .isnumeric()
# ***
# - .removeprefix(prefix,/)
# - .removesuffix(suffix,/)
# - .partition(sep)
# - .rpartition(sep)

# %% [markdown]
# ## 2.2 bytes

# %% [markdown]
# bytes()

# %% [markdown]
# ## 2.3 bytearray

# %% [markdown]
# bytearray()

# %% [markdown]
# ## 2.4 range

# %% [markdown]
# - range(value)
# - range(start,stop)
# - range(start,stop,step)

# %% [markdown]
# # 3) List

# %% [markdown]
# ## 3.1 list

# %% [markdown]
# ### general info

# %% [markdown]
# - ordered collection of Heterogeneous objects, allows duplicates also.
# - [],list(Iterableobject)
# - Supports Indexing, Slicing
# - we can use slicing to modify list in-place
# - +, *
# - array of variables not data ---> variables can hold any type of data.
# ***
# LIST IN SET ---- NO <br>
# LIST IN LIST ---- OK <br>
# LIST IN TUPLE ---- OK <br>

# %% [markdown]
# ### methods

# %% [markdown]
# - .append(value)
# - .insert(index,value)
# - .remove(value) E
# - .pop(index) E
# - .pop([i]) E
# - .clear()
# - del listObj, del listObj[index] E, del listObj[start:stop], del listObj[start:stop:step]
# - .index(value[,start[,end]]) VE ---> end-1
# - .count(value)
# - .copy() shallow copy  * careful with nested lists items are referenced changes will be reflected
# - slice copy always shallow copy * careful with nested lists items are referenced changes will be reflected
# - import copy -----> copy.deepcopy(listObj)
# - .reverse()
# - .sort(*,key = None,reverse=False) E if provided hetrogenous data
# - .extend(iterable)

# %% [markdown]
# ## 3.2 tuple

# %% [markdown]
# ### general info

# %% [markdown]
# - (),tuple(Iterableobject),(val1,...) or val,
# - Indexing, Slicing
# - +, *
# - Unpacking happens with all iterables
# - packing happens only in the form of tuple
# ***
# TUPLE IN SET ---- OK <br>
# TUPLE IN LIST ----- OK <br>
# TUPLE IN TUPLE ----- OK <br>

# %% [markdown]
# ### methods

# %% [markdown]
# - .index(value) E
# - .count(value)
# - sorted(tupleObj) ---> listObj

# %% [markdown]
# # 4) Set

# %% [markdown]
# ## 4.1 set

# %% [markdown]
# ### general info

# %% [markdown]
# - unordered, hetrogeneous, no duplicates, growable
# - set() or {val1,val2,...,val-n} Unique Values/KEYS
# - CANNOT INDEX OR SLICE (hashing, hash table, hash function)
# - =, !=
# ***
# SET IN SET --- NO <br>
# FROZEN SET IN SET --- OK <br>
# SET IN LIST ---- OK <br>
# SET IN TUPLE ---- OK <br>

# %% [markdown]
# ### methods

# %% [markdown]
# - .add(value)
# - .remove(value) E
# - .discard(value)
# - .pop() E ---> arbitary element
# - .clear()
# - .union(iterable) ---> |
# - .intersection(iterable) ----> &
# - .intersection_update(iterable)
# - .difference(iterable) ----> -
# - .difference_update(iterable)
# - .symmetric_difference(iterable) -----> ^
# - .symmetric_difference_update(iterable)
# - .update(iterable)
# - .isdisjoint(iterable)
# - .issubset(iterable) --> < <=
# - .issuperset(iterable) --> > >=
# - .copy()

# %% [markdown]
# ## 4.2 frozenset

# %% [markdown]
# ### methods

# %% [markdown]
# - .isdisjoint()
# - .issubset()
# - .issuperset()
# - .union()
# - .intersection()
# - .difference()
# - .symmetric_difference()
# - .update()
# - .copy() -----> deep copy

# %% [markdown]
# # 5) Dict

# %% [markdown]
# ## 5.1 dict

# %% [markdown]
# ### general info

# %% [markdown]
# - keys are not mutable but values of keys are mutable
# - {}, {key:value,...}, dict([(,)])
# - Cannot Index or Slice
# - keys Immutable
# - Values any datatype
# - dictObj[key] E
# - dictObj[key] = value

# %% [markdown]
# ### methods

# %% [markdown]
# - .clear()
# - .pop(key,default) E
# - .popitem() E
# - .copy()
# - .get(key,default=None) ---> value or None
# - .keys()
# - .values()
# - .items()
# - .update(iterable)
# - del dictobj[key]
# - .setdefault(key,default)
# - .fromkeys(iterable,value=None)

# %% [markdown]
# # 6) NoneType

# %% [markdown]
# ## 6.1 None

# %% [markdown]
# None

# %% [markdown]
# # Type Casting

# %% [markdown]
# ## int

# %% [markdown]
# - int
# - float
# - bool
# - complex-TE
# - strInt
# - strFloat-VE
# - strBool-VE
# - strComplex-VE
# - str-VE

# %% [markdown]
# ## float

# %% [markdown]
# - int
# - float
# - bool
# - complex-TE
# - strInt
# - strFloat
# - strBool-VE
# - strComplex-VE
# - str-VE

# %% [markdown]
# ## bool

# %% [markdown]
# True for 1 or populated objects False for 0 or any empty objects

# %% [markdown]
# ## complex

# %% [markdown]
# - int
# - float
# - bool
# - complex
# - strInt
# - strFloat
# - strBool-VE
# - strComplex
# - str-VE

# %% [markdown]
# ## str

# %% [markdown]
# All Acceptable
