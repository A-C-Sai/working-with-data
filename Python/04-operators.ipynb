# %%
from IPython.display import Image

# %% [markdown]
# # Operators

# %% [markdown]
# ## 1) Arthemetic

# %% [markdown]
# - \+
# - \-
# - %
# - /
# - //
# - \*
# - **
# - ()

# %% [markdown]
# +=,-=,*=,/=,%=,//=,**=

# %%
Image(filename=f'./resources/operators1.png')

# %%
Image(filename=f'./resources/operators2.png')

# %%
Image(filename=f'./resources/operators3.png')

# %%
Image(filename=f'./resources/operators4.png')

# %%
Image(filename=f'./resources/operators5.png')

# %%
Image(filename=f'./resources/operators6.png')

# %% [markdown]
# ## 2) Assignment

# %% [markdown]
# = single line assignment or multi\-line assignment

# %% [markdown]
# ## 3) Relational

# %%
Image(filename=f'./resources/operators7.png')

# %% [markdown]
# Note: I have noticed these work on lists and tuples checks element wise.

# %%
'''
x == y 
This expression evaluates if x and y are the same value and returns the result as a boolean value. Generally both
type and value need to match.


In order to compare the equality of custom classes, you can override == and != by defining __eq__ and __ne__
methods. You can also override __lt__ (<), __le__ (<=), __gt__ (>), and __ge__ (>). Note that you only need to
override two comparison methods, and Python can handle the rest (== is the same as not < and not >, etc.)

'''
print()

# %% [markdown]
# ## 4) Logical

# %% [markdown]
# Logical ------> not and or -------> True False ------> short circuit

# %% [markdown]
# ## 5) Bitwise

# %% [markdown]
# Bitwise ------> << >> & | ~ ^
# - << value*(2**no.of bits)
# - \>> value//(2**no.of bits)
# - ~   -(value+1)
# - ^  same 0 diff 1

# %% [markdown]
# &=,|=,~=,^=,>>=,<<=

# %% [markdown]
# ## 6) Membership

# %% [markdown]
# Membership ------> in, not in ---> True False

# %%
a = 3

if a == 2 or a == 4 or a==3:
    print("code is lengthy")
# Out:
# code is lengthy

# %%
b = 2

if b in (2,3,4):
    print("that's better")
# Out:
# that's better

# %% [markdown]
# ## 7) Identity

# %% [markdown]
# Identity ------> is, is not -----> True False

# %%
"""
							
	- None 	 [is]
	- dict	 [is not]
	-set/frozenset	 [is not]
	- list/tuple   [is not]
	- range  [is not]
	- bytearray 	[is not]
	- bytes	 [is not]
	- str   [is]	
	- complex	 [is not]
	- bool	 [is]	
	- float	  [is not]
	- int [-1,-5] [0-256] [is]	[is not] (others)
 
	Multiline Assignment:
	- int 	[is]			
	- float	[is]
	- bool	[is]
	- complex [is]
	- str	[is]
"""
print()

# %%
def foo():
    pass
    
a = foo()

if a == None:
    print("can be better")

if a is None: # pythonic way
    print("thats better")
# Out:
# can be better
# thats better

# %%
'''
Note:
    a == b compares the value of a and b.
    a is b will compare the identitied of a and b.

    is can be thought of as shorthand for id(a) == id(b).
'''
print()

# %% [markdown]
# ## 8) if else

# %%
'''
varname = <value-if-condition-is-true> if <condition> else <value-if-condition-is-false>
'''
print()

# %% [markdown]
# ## 9) Order

# %%
Image(filename='./resources/operators8.png')
