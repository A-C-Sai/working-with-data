# %%
from IPython.display import Image

# %% [markdown]
# # Question

# %% [markdown]
# **For more information about the question click the provided links**

# %% [markdown]
# ## Easy

# %% [markdown]
# ***

# %% [markdown]
# ### Google | Companies With Chinese Speakers

# %% [markdown]
# [Question](https://platform.stratascratch.com/coding/9685-companies-with-chinese-speakers?code_type=3): <br>
# Find companies that have at least 2 Chinese speaking users.

# %% [markdown]
# ```sql
# select
#     company_id
# from playbook_users
# where language like "chinese"
# group by company_id
# having count(language) >= 2;
# ```

# %%
Image(filename='./resources/1.png')

# %% [markdown]
# ***

# %% [markdown]
# ### Netflix | Find details of oscar winners between 2001 and 2009

# %% [markdown]
# [Question](https://platform.stratascratch.com/coding/9687-find-details-of-oscar-winners-between-2001-and-2009?code_type=3): <br>
# Find the details of oscar winners between 2001 and 2009.

# %% [markdown]
# ```sql
# select
#     *
# from oscar_nominees
# where
#     winner = TRUE AND
#     year BETWEEN 2001 AND 2009;
# ```

# %%
Image(filename='./resources/2.png')

# %% [markdown]
# ***

# %% [markdown]
# ### Meta | List all interactions of user wth id 4 on either day 0 or 2

# %% [markdown]
# [Question](https://platform.stratascratch.com/coding/9765-list-all-interactions-of-user-wth-id-4-on-either-day-0-or-2?code_type=3): <br>
# List all interactions of user with id 4 on either day 0 or 2.

# %% [markdown]
# ```sql
# select
#     *
# from facebook_user_interactions
# where
#     (user1 = 4 OR user2 = 4) AND
#     day in (0,2);
# ```

# %%
Image(filename='./resources/3.png')

# %% [markdown]
# ***

# %% [markdown]
# ### Forbes | Highest Market Value Per Sector

# %% [markdown]
# [Question](https://platform.stratascratch.com/coding/9681-highest-market-value-per-sector?code_type=3): <br>
# Find the highest market value for each sector.
# Output the sector name along with the result.

# %% [markdown]
# ```sql
# select
#     sector,
#     MAX(marketvalue) as marketvalue
# from forbes_global_2010_2014
# group by 1;
# ```

# %%
Image(filename='./resources/4.png')
