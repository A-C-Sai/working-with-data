# %%
from IPython.display import Image

# %% [markdown]
# # Questions

# %% [markdown]
# **For more information about the question, please click the provided links**

# %% [markdown]
# ## Easy

# %% [markdown]
# ***

# %% [markdown]
# ### Asana | Winning on Your First Roll

# %% [markdown]
# [Question](https://platform.stratascratch.com/technical/2438-winning-on-your-first-roll):<br>
# You are playing a game with a friend where you roll two fair six-sided dice. If the sum of the two dice is 7 or 11, you win; otherwise, your friend wins. What is the probability that you win on your first roll?

# %%
Image(filename='./resources/asana.png',width=500)

# %% [markdown]
# ***

# %% [markdown]
# ### Google | Four People in an Elevator

# %% [markdown]
# [Question](https://platform.stratascratch.com/technical/2358-four-people-in-an-elevator):<br>
# There are four people in an elevator that is about to make four stops on four different floors of the building. What is the probability that each person gets off on a different floor?

# %%
Image(filename='./resources/google.png',width=600)

# %% [markdown]
# ***

# %% [markdown]
# ### Walmart | Rolling Two Dice

# %% [markdown]
# [Question](https://platform.stratascratch.com/technical/2313-rolling-two-dice):<br>
# Suppose you roll a die and earn whatever face you get. Now suppose you have a chance to roll a second die. If you roll, you earn whatever face you get but you forfeit earnings from the first round. When should you roll the second time?

# %%
Image(filename='./resources/walmart.png',width=600)

# %% [markdown]
# ***

# %% [markdown]
# ### Peak6 | Combinations Of Three

# %% [markdown]
# [Question](https://platform.stratascratch.com/technical/2288-combinations-of-three):<br>
# Three people, and 1st, 2nd and 3rd places at a competition, how many different combinations are there?

# %%
Image(filename='./resources/peak6.png',width=600)

# %% [markdown]
# ***

# %% [markdown]
# ### Jane Street | Two Out Of Five

# %% [markdown]
# [Question](https://platform.stratascratch.com/technical/2283-two-out-of-five):<br>
# What's the probability of obtaining 2 tails in 5 coin flips?

# %%
Image(filename='./resources/janeStreet1.png',width=600)

# %% [markdown]
# ***

# %% [markdown]
# ### Jane Street | 7th-Game Achievement

# %% [markdown]
# [Question](https://platform.stratascratch.com/technical/2279-7th-game-achievement):<br>
# Two teams are playing a best-of-7 tournament. Each team has a 50% chance of winning. What is the probability that they reach the 7th game?

# %%
Image(filename='./resources/janeStreet2.png',width=600)

# %% [markdown]
# ***

# %% [markdown]
# ### Jane Str | T

# %% [markdown]
# [Question]():<br>

# %%
#Image(filename='./resources/google.png',width=600)

# %% [markdown]
# ***

# %% [markdown]
# ### C | T

# %% [markdown]
# [Question]():<br>

# %%
#Image(filename='./resources/google.png',width=600)

# %% [markdown]
# ***
