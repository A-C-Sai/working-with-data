# %%
from IPython.display import Image

# %% [markdown]
# # Questions

# %% [markdown]
# **For more information about the question, please click the provided links**

# %% [markdown]
# ***

# %% [markdown]
# ### JPMorgan | Two Consecutive Sixes

# %% [markdown]
# [Question](https://datalemur.com/questions/two-consecutive-sixes):<br>
# Say you roll a die three times. What is the probability of getting two sixes in a row?

# %%
Image(filename='./resources/two-consecutive-sixes.png',width=600)

# %% [markdown]
# ***

# %% [markdown]
# ### C | T

# %% [markdown]
# [Question]():<br>

# %%
#Image(filename='./resources/filename.png',width=500)

# %% [markdown]
# ***

# %% [markdown]
# ### C | T

# %% [markdown]
# [Question]():<br>

# %%
#Image(filename='./resources/filename.png',width=500)

# %% [markdown]
# ***
