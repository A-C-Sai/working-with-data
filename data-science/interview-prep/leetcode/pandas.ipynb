# %%
from IPython.display import Image

# %% [markdown]
# # Questions

# %% [markdown]
# **For more information about the question, please click the provided links**

# %% [markdown]
# ***

# %% [markdown]
# ### 2877. Create a DataFrame from List

# %% [markdown]
# [Question](https://leetcode.com/problems/create-a-dataframe-from-list/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# Write a solution to create a DataFrame from a 2D list called student_data. This 2D list contains the IDs and ages of some students.
#
# The DataFrame should have two columns, student_id and age, and be in the same order as the original 2D list.

# %% [markdown]
# ```python
# import pandas as pd
#
# def createDataframe(student_data: List[List[int]]) -> pd.DataFrame:
#     return pd.DataFrame(student_data,columns=['student_id','age'])
# ```

# %%
Image(filename='./resources/2877.png',width=700)

# %% [markdown]
# ***

# %% [markdown]
# ### 2878. Get the Size of a DataFrame

# %% [markdown]
# [Question](https://leetcode.com/problems/get-the-size-of-a-dataframe/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# Write a solution to calculate and display the number of rows and columns of players.
#
# Return the result as an array:
#
# \[number of rows, number of columns\]

# %% [markdown]
# ```python
# import pandas as pd
#
# def getDataframeSize(players: pd.DataFrame) -> List[int]:
#     return list(players.shape)
# ```

# %%
Image(filename='./resources/2878.png',width=700)

# %% [markdown]
# ***

# %% [markdown]
# ### 2879. Display the First Three Rows

# %% [markdown]
# [Question](https://leetcode.com/problems/display-the-first-three-rows/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# Write a solution to display the first 3 rows of this DataFrame.

# %% [markdown]
# ```python
# import pandas as pd
#
# def selectFirstRows(employees: pd.DataFrame) -> pd.DataFrame:
#     return employees.head(3)
# ```

# %%
Image(filename='./resources/2879.png',width=700)

# %% [markdown]
# ***

# %% [markdown]
# ### 2880. Select Data

# %% [markdown]
# [Question](https://leetcode.com/problems/select-data/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# Write a solution to select the name and age of the student with student_id = 101.

# %% [markdown]
# ```python
# import pandas as pd
#
# def selectData(students: pd.DataFrame) -> pd.DataFrame:
#     return students[students['student_id']==101][['name','age']]
# ```

# %%
Image(filename='./resources/2880.png',width=300)

# %% [markdown]
# ***

# %% [markdown]
# ### 2881. Create a New Column

# %% [markdown]
# [Question](https://leetcode.com/problems/create-a-new-column/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# A company plans to provide its employees with a bonus.
#
# Write a solution to create a new column name bonus that contains the doubled values of the salary column.

# %% [markdown]
# ```python
# import pandas as pd
#
# def createBonusColumn(employees: pd.DataFrame) -> pd.DataFrame:
#     return employees.assign(
#         bonus = employees["salary"]*2
#     )
# ```

# %%
Image(filename='./resources/2881.png',width=250)

# %% [markdown]
# ***

# %% [markdown]
# ### 2882. Drop Duplicate Rows

# %% [markdown]
# [Question](https://leetcode.com/problems/drop-duplicate-rows/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# There are some duplicate rows in the DataFrame based on the email column.
#
# Write a solution to remove these duplicate rows and keep only the first occurrence.

# %% [markdown]
# ```python
# import pandas as pd
#
# def dropDuplicateEmails(customers: pd.DataFrame) -> pd.DataFrame:
#     return customers.drop_duplicates(subset=["email"],keep="first")
# ```

# %%
Image(filename='./resources/2882.png',width=400)

# %% [markdown]
# ***

# %% [markdown]
# ### 2883. Drop Missing Data

# %% [markdown]
# [Question](https://leetcode.com/problems/drop-missing-data/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# There are some rows having missing values in the name column.
#
# Write a solution to remove the rows with missing values.

# %% [markdown]
# ```python
# import pandas as pd
#
# def dropMissingData(students: pd.DataFrame) -> pd.DataFrame:
#     return students.dropna(axis = "index", subset="name")
# ```

# %%
Image(filename='./resources/2883.png',width=300)

# %% [markdown]
# ***

# %% [markdown]
# ### 2884. Modify Columns

# %% [markdown]
# [Question](https://leetcode.com/problems/modify-columns/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# A company intends to give its employees a pay rise.
#
# Write a solution to modify the salary column by multiplying each salary by 2.

# %% [markdown]
# ```python
# import pandas as pd
#
# def modifySalaryColumn(employees: pd.DataFrame) -> pd.DataFrame:
#     return employees.assign(
#         salary = employees["salary"]*2
#     )
# ```

# %%
Image(filename='./resources/2884.png',width=200)

# %% [markdown]
# ***

# %% [markdown]
# ### 2885. Rename Columns

# %% [markdown]
# [Question](https://leetcode.com/problems/rename-columns/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# Write a solution to rename the columns as follows:
# - id to student_id
# - first to first_name
# - last to last_name
# - age to age_in_years

# %% [markdown]
# ```python
# import pandas as pd
#
# def renameColumns(students: pd.DataFrame) -> pd.DataFrame:
#     return students.rename(columns={"id":"student_id",
#                                     "first":"first_name",
#                                     "last":"last_name",
#                                     "age":"age_in_years"
#                                     })
# ```

# %%
Image(filename='./resources/2885.png',width=400)

# %% [markdown]
# ***

# %% [markdown]
# ### 2886. Change Data Type

# %% [markdown]
# [Question](https://leetcode.com/problems/change-data-type/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# Write a solution to correct the errors:
#
# The grade column is stored as floats, convert it to integers.

# %% [markdown]
# ```python
# import pandas as pd
#
# def changeDatatype(students: pd.DataFrame) -> pd.DataFrame:
#     return students.assign(
#         grade = students["grade"].astype("int")
#     )
# ```

# %%
Image(filename='./resources/2886.png',width=400)

# %% [markdown]
# ***

# %% [markdown]
# ### 2887. Fill Missing Data

# %% [markdown]
# [Question](https://leetcode.com/problems/fill-missing-data/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# Write a solution to fill in the missing value as 0 in the quantity column.

# %% [markdown]
# ```python
# import pandas as pd
#
# def fillMissingValues(products: pd.DataFrame) -> pd.DataFrame:
#     products['quantity'].fillna(0,inplace=True)
#     return products
# ```

# %%
Image(filename='./resources/2887.png',width=400)

# %% [markdown]
# ***

# %% [markdown]
# ### 2888. Reshape Data: Concatenate

# %% [markdown]
# [Question](https://leetcode.com/problems/reshape-data-concatenate/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# Write a solution to concatenate these two DataFrames vertically into one DataFrame.

# %% [markdown]
# ```python
# import pandas as pd
#
# def concatenateTables(df1: pd.DataFrame, df2: pd.DataFrame) -> pd.DataFrame:
#     return pd.concat([df1,df2],axis="index",ignore_index=True)
# ```

# %%
Image(filename='./resources/2888.png',width=300)

# %% [markdown]
# ***

# %% [markdown]
# ### 2889. Reshape Data: Pivot

# %% [markdown]
# [Question](https://leetcode.com/problems/reshape-data-pivot/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# Write a solution to pivot the data so that each row represents temperatures for a specific month, and each city is a separate column.

# %% [markdown]
# ```python
# import pandas as pd
#
# def pivotTable(weather: pd.DataFrame) -> pd.DataFrame:
#     return weather.pivot(index = 'month', columns = 'city', values = 'temperature')
# ```

# %%
Image(filename='./resources/2889.png',width=400)

# %% [markdown]
# ***

# %% [markdown]
# ### 2890. Reshape Data: Melt

# %% [markdown]
# [Question](https://leetcode.com/problems/reshape-data-melt/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# Write a solution to reshape the data so that each row represents sales data for a product in a specific quarter.

# %% [markdown]
# ```python
# import pandas as pd
#
# def meltTable(report: pd.DataFrame) -> pd.DataFrame:
#     return report.melt(id_vars="product",var_name="quarter",value_name="sales")
# ```

# %%
Image(filename='./resources/2890.png',width=500)

# %% [markdown]
# ***

# %% [markdown]
# ### 2891. Method Chaining

# %% [markdown]
# [Question](https://leetcode.com/problems/method-chaining/description/?envType=study-plan-v2&envId=introduction-to-pandas&lang=pythondata):<br>
# Write a solution to list the names of animals that weigh strictly more than 100 kilograms.
#
# Return the animals sorted by weight in descending order.

# %% [markdown]
# ```python
# import pandas as pd
#
# def findHeavyAnimals(animals: pd.DataFrame) -> pd.DataFrame:
#     return animals[animals['weight']>100].sort_values(by="weight",ascending=False)[["name"]]
# ```

# %%
Image(filename='./resources/2891.png',width=400)

# %% [markdown]
# ***

# %% [markdown]
# ### Q

# %% [markdown]
# [Question]():<br>

# %% [markdown]
# ```python
# ```

# %%
#Image(filename='./resources/2877.png',width=700)

# %% [markdown]
# ***
