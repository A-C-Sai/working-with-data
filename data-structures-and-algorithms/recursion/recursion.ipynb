# %%
from IPython.display import Image

# %%
''' 
Tracing tree of recursion function

Calling and Returning phase

Recursion uses stack (memory consuming functions)

Recurrence Relation (solve by induction/successive substitution)

static - always in memory but accessible by the function in which they are declared (spoce limited to a function)
and global variables - always in memory and accessible by all functions
can help  us in recursion
'''
print()

# %%
""" General Form

Type fun(param)
{
    if(<base_condition>)
    {
        1. Calling
        2. fun(param)
        3. Returning
    }

}
"""
print()

# %%
""" Types of Recursions

1. Tail Recursion
    - All work done during calling phase
    - Tail Recursion can be easily converted in the form of loops
    - if we have to write a tail recursion, better to convert it into a loop as it is more space efficient.

2. Head Recursion
    - All work done during returning phase
    - Not easy to convert in the form of a loop and might not look as it is.

3. Tree Recursion
    - Linear Recursion : function calling itself only one time
    - If a recursive function is calling itself more than once

4. Indirect Recursion
    - There may be more than 1 function and they are calling one another in a circular fashion.
    - A->B->C->A......

5. Nested Recursion
    - Recursive function will pass paramater as a recursive call
"""
print()

# %%
# %%file r.c
# #include <stdio.h>
# void fun1(int i) {
#
#     if (i>0) {
#         printf("%d ",i);
#         fun1(i-1);
#     }
# }
#
# void fun2(int i) {
#
#     if (i>0) {
#         fun2(i-1);
#         printf("%d ",i);
#     }
# }
#
# int main() {
#
#     fun2(5);
#     printf("\n");
#     fun1(5);
#
#     return 0;
# }
# Out:
# Overwriting r.c

# %%
# %%bash
# gcc r.c -o r
# ./r
# Out:
# 1 2 3 4 5
# 5 4 3 2 1

# %% [markdown]
# # Sum of Natural Number using Recursion

# %%
Image(filename="./resources/recursion1.png")

# %%
# %%file r1.c
# #include <stdio.h>
# int sum(int n) {
#     if(n==0){
#         return 0;
#     }
#     return sum(n-1)+n;
# }
# int main() {
#     printf("%d\n",sum(5));
#     return 0;
# }
# Out:
# Overwriting r1.c

# %%
# %%bash
# gcc r1.c -o r1
# ./r1
# Out:
# 15

# %% [markdown]
# # Factorial using Recursion

# %%
Image(filename='./resources/recursion2.png')

# %%
# %%file r2.c
# #include <stdio.h>
# int fact(int n) {
#
#     if (n==0){
#         return 1;
#     }
#     return fact(n-1)*n;
# }
#
# int main() {
#
#     printf("%d\n",fact(5));
#     return 0;
# }
# Out:
# Overwriting r2.c

# %%
# %%bash
# gcc r2.c -o r2
# ./r2
# Out:
# 120

# %% [markdown]
# # m<sup>n</sup> using Recursion

# %%
Image(filename='./resources/recursion3.png')

# %%
Image(filename='./resources/recursion4.png')

# %%
""" Reduced Number Of Multiplications
2^8 = (2^2)^4 = (m*m)^(n/2)

2^9 = 2 * (2^2)^4 = m * (m*m)^((n-1)/2)

"""
print()

# %%
# %%file r3.c
# #include <stdio.h>
# int expo(int m, int n) {
#     if(n==0){
#         return 1;
#     }
#     if(n%2==0){
#         return expo(m*m,n/2);
#     }
#
#     return m*expo(m*m,(n-1)/2);
# }
# int main() {
#
#     printf("%d\n",expo(2,10));
#     return 0;
# }
# Out:
# Overwriting r3.c

# %%
# %%bash
# gcc r3.c -o r3
# ./r3
# Out:
# 1024
