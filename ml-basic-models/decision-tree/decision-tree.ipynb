# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
from tree import (
    DTreeClassifier,
    DTreeRegressor
)
from sklearn.tree import (
    DecisionTreeClassifier,
    DecisionTreeRegressor
)
from sklearn import tree
from sklearn.datasets import (
    load_iris,
    load_diabetes
)
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import pprint
import matplotlib.pyplot as plt

# %% [markdown]
# # Datasets

# %%
df = pd.read_csv('titanic.csv') # Read titanic dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#simple preprocessing
df['Age'].fillna(df['Age'].mean(), inplace = True)  # Replace with average
df['Embarked'].fillna('N', inplace = True)          # Replace with 'N'
df['Sex'] = df['Sex'].factorize()[0]                # label encoding
df['Embarked'] = df['Embarked'].factorize()[0]      # label encoding
df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
df
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0           0       3    0  22.000000      1      0   7.2500         0
# 1           1       1    1  38.000000      1      0  71.2833         1
# 2           1       3    1  26.000000      0      0   7.9250         0
# 3           1       1    1  35.000000      1      0  53.1000         0
# 4           0       3    0  35.000000      0      0   8.0500         0
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    0  27.000000      0      0  13.0000         0
# 887         1       1    1  19.000000      0      0  30.0000         0
# 888         0       3    1  29.699118      1      2  23.4500         0
# 889         1       1    0  26.000000      0      0  30.0000         1
# 890         0       3    0  32.000000      0      0   7.7500         2
#
# [891 rows x 8 columns]

# %%
# split the data into train and test data.
y = np.array(df['Survived'])
x = np.array(df.drop('Survived', axis=1))
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
# Load iris dataset
iris_x, iris_y = load_iris(return_X_y=True)
# Generate training and test data
iris_x_train, iris_x_test, iris_y_train, iris_y_test = train_test_split(iris_x, iris_y)

# %%
# Load diabetes dataset
data = load_diabetes(as_frame=True)['frame']
# Generate training and test data
r_x_train, r_x_test, r_y_train, r_y_test = train_test_split(data.iloc[:,:-1].values, data['target'].values)

# %% [markdown]
# # Binary Classification Testing (DTreeClassifier vs sklearn)

# %%
depth = 1
my_model = DTreeClassifier(max_depth = depth)
my_model.fit(x_train, y_train)
my_pred = my_model.predict(x_test)
acc = (y_test == my_pred).mean()
print('MyTreeClassifier: accuracy = {:.3f}'.format(acc))
# Out:
# MyTreeClassifier: accuracy = 0.803

# %%
# Compare the results with sklearn's DecisionTreeClassifier.
# ----------------------------------------------------------
sk_model = DecisionTreeClassifier(max_depth=depth, 
                                  random_state=1)
sk_model.fit(x_train, y_train)
sk_pred = sk_model.predict(x_test)
acc = (y_test == sk_pred).mean()
print('DecisionTreeClassifier: accuracy = {:.3f}'.format(acc))

print('\nMyTreeClassifier: estimator2:')
pprint.pprint(my_model.estimator2, sort_dicts=False)

plt.figure(figsize=(12, 6))
tree.plot_tree(sk_model)
plt.show()
# Out:
# DecisionTreeClassifier: accuracy = 0.803
#
# MyTreeClassifier: estimator2:
# {'is_leaf': False,
#  'fid': 1,
#  'split_point': 0.5,
#  'left_child': 0,
#  'right_child': 1}

# %% [markdown]
# # Analyse the importance of features

# %%
# Train model
clf = DecisionTreeClassifier(max_depth=3)
clf.fit(x_train[:,[0,1,2]],y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
# Visualize the tree
plt.figure(figsize=(20,10))
tree.plot_tree(clf, feature_names=['Pclass','Sex','Age'], fontsize=10)
plt.show()

# %%
# Analyse the importance of features
feature_importance = clf.feature_importances_
n_feature = 3
idx = np.arange(n_feature)

# %%
plt.barh(idx,feature_importance,align='center')
plt.yticks(idx,['Pclass','Sex','Age'],size=12)
plt.xlabel('importance',size=15)
plt.ylabel('feature',size=15)
plt.show()

# %%
feature_importance
# Out:
# array([0.22944814, 0.65022399, 0.12032788])

# %% [markdown]
# # Cost Complexity Pruning

# %%
# Apply Cost Complexity Pruning and get the alpha-star list
dt = DecisionTreeClassifier()
path = dt.cost_complexity_pruning_path(x_train,y_train)

# %%
ccp_alpha=path.ccp_alphas[:-1]
impurity=path.impurities[:-1]

# %%
# observe impurity changes as alpha changes
# As alpha increases the penalty |T| increases, resulting
# in simple trees and increased impurity (misclassification error)
plt.figure(figsize=(7,4))
plt.plot(ccp_alpha,impurity,marker='o')
plt.xlabel('effective alpha')
plt.ylabel('total impurity')
plt.title('total impurity vs effective alpha for training set')
plt.show()

# %%
# Create trees for each alpha in the alpha-list
models=[]
for alpha in ccp_alpha:
    model=DecisionTreeClassifier(ccp_alpha=alpha)
    model.fit(x_train,y_train)
    models.append(model)

# %%
# node count and depth vs alpha
node_counts=[model.tree_.node_count for model in models]
depth=[model.tree_.max_depth for model in models]

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(ccp_alpha,node_counts,marker='o')
ax[0].set_xlabel('alpha')
ax[0].set_ylabel('number of nodes')
ax[0].set_title('Number of nodes vs alpha')
ax[1].plot(ccp_alpha,depth,marker='o')
ax[1].set_xlabel('alpha')
ax[1].set_ylabel('depth of tree')
ax[1].set_title('Depth of tree vs alpha')
fig.tight_layout()

# %% [markdown]
# # Multi-Class Classification Testing (DTreeClassifier vs sklearn)

# %%
model1 = DTreeClassifier(max_depth=2)
model1.fit(iris_x_train, iris_y_train)

# Estimate the class of test data.
y_pred1 = model1.predict(iris_x_test)

# Measure the accuracy for test data
accuracy1 = (iris_y_test == y_pred1).mean()
print('\nAccuracy of Model-1 = {:.3f}'.format(accuracy1))


model2 = DecisionTreeClassifier(max_depth=2)
model2.fit(iris_x_train, iris_y_train)

# Estimate the class of validation date.
y_pred2 = model2.predict(iris_x_test)

# Measure the accuracy for validation data
accuracy2 = (iris_y_test == y_pred2).mean()
print('Accuracy of Model-2 = {:.3f}'.format(accuracy2))

print("\nModel-1: y_pred1")
print(y_pred1)
print("\nModel-2: y_pred2")
print(y_pred2)
# Out:
# Accuracy of Model-1 = 0.947
# Accuracy of Model-2 = 0.947
#
# Model-1: y_pred1
# [1 0 1 1 1 0 2 2 0 2 1 0 0 1 2 1 2 2 2 0 1 2 2 1 0 1 0 1 0 0 0 1 1 1 1 2 1
#  2]
#
# Model-2: y_pred2
# [1 0 1 1 1 0 2 2 0 2 1 0 0 1 2 1 2 2 2 0 1 2 2 1 0 1 0 1 0 0 0 1 1 1 1 2 1
#  2]

# %%
print('\nModel-1: estimator2:')
pprint.pprint(model1.estimator2, sort_dicts=False)

plt.figure(figsize=(12, 6))
tree.plot_tree(model2)
plt.show()
# Out:
# Model-1: estimator2:
# {'is_leaf': False,
#  'fid': 2,
#  'split_point': 2.35,
#  'left_child': 0,
#  'right_child': {'is_leaf': False,
#                  'fid': 3,
#                  'split_point': 1.65,
#                  'left_child': 1,
#                  'right_child': 2}}

# %% [markdown]
# # Regression Test (DTreeRegressor vs sklearn)

# %%
depth = 2
model1 = DTreeRegressor(max_depth = depth)
model1.fit(r_x_train, r_y_train)
my_pred = model1.predict(r_x_test)
model1_r2 = r2_score(r_y_test,my_pred)
print('MyTreeRegressor: r2_score = {:.3f}'.format(model1_r2))
# Out:
# MyTreeRegressor: r2_score = 0.300

# %%
# Compare the results with sklearn's DecisionTreeRegressor.
# ----------------------------------------------------------
model2 = DecisionTreeRegressor(max_depth=depth, 
                                  random_state=1)
model2.fit(r_x_train, r_y_train)
sk_pred = model2.predict(r_x_test)
model2_r2 = r2_score(r_y_test,sk_pred)
print('DecisionTreeRegressor: r2_score = {:.3f}'.format(model2_r2))

print('\nMyTreeRegressor: estimator2:')
pprint.pprint(model1.estimator2, sort_dicts=False)

plt.figure(figsize=(12, 6))
tree.plot_tree(model2)
plt.show()
# Out:
# DecisionTreeRegressor: r2_score = 0.300
#
# MyTreeRegressor: estimator2:
# {'is_leaf': False,
#  'fid': 8,
#  'split_point': -0.0010538420311457788,
#  'left_child': {'is_leaf': False,
#                 'fid': 2,
#                 'split_point': 0.0061888847138220964,
#                 'left_child': 94.78294573643412,
#                 'right_child': 163.15},
#  'right_child': {'is_leaf': False,
#                  'fid': 2,
#                  'split_point': 0.05576824011233889,
#                  'left_child': 178.225,
#                  'right_child': 254.35714285714286}}
