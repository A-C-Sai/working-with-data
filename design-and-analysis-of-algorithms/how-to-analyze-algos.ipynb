# %%
from IPython.display import Image

# %%
'''
Criteria  on which we analyze algorithms:

1. Time --> Time Function
2. Space --> Space Function

Additional criteria depend on given requirements.

-> Every simple statement in the algorithm takes 1 unit of time
-> Each variable 

'''
print()

# %%
Image(filename='fmc1.png')

# %%
Image(filename='fmc2.png')

# %%
Image(filename='fmc3.png')
