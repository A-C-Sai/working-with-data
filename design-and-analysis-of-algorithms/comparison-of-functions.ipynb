# %%
from IPython.display import Image

# %%
'''
1. sample some values
2. apply log to both sides

'''
print()

# %%
Image(filename='./resources/log.png')

# %%
Image(filename='./resources/compare-functions-1.png')

# %%
Image(filename='./resources/compare-functions-2.png')

# %%
'''
Note: After applying log don't ignore coefficients.

If from a certain point, one function is is greater than another, then that function is greater asymptotically.
'''
